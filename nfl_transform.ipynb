# %%
import pandas as pd

# %%
nfl_df = pd.read_csv("nfl_data.csv")

# %%
nfl_df.head()
# Out:
#        date      away     home  passing_yards_home  rushing_yards_away  \
# 0  9/5/2002     49ers   Giants                 318                 113
# 1  9/8/2002      Jets    Bills                 242                  73
# 2  9/8/2002   Vikings    Bears                 288                 140
# 3  9/8/2002  Chargers  Bengals                 167                 241
# 4  9/8/2002    Chiefs   Browns                 352                 194
#
#    rushing_yards_home  total_yards_away  total_yards_home comp_att_away  \
# 0                  43               279               361         16-26
# 1                 142               266               384         24-30
# 2                  80               368               368         16-28
# 3                  36               401               203         15-19
# 4                  59               470               411         20-29
#
#   comp_att_home  ... fumbles_home int_away  int_home  turnovers_away  \
# ...

# %%
my_list = nfl_df.columns.values.tolist()
print(my_list)
# Out:
# ['date', 'away', 'home', 'passing_yards_home', 'rushing_yards_away', 'rushing_yards_home', 'total_yards_away', 'total_yards_home', 'comp_att_away', 'comp_att_home', 'sacks_away', 'sacks_home', 'rushing_attempts_away', 'rushing_attempts_home', 'fumbles_away', 'fumbles_home', 'int_away', 'int_home', 'turnovers_away', 'turnovers_home', 'penalties_away', 'penalties_home', 'def_st_td_home', 'score_away', 'score_home']

# %%
unnecessary = ["first_downs_away", "first_downs_home", "third_downs_away", "third_downs_home", "fourth_downs_away", "fourth_downs_home",
              "passing_yards_away", "redzone_away", "redzone_home", "drives_away", "drives_home", "def_st_td_away",
              "possession_away", "possession_home"] 
nfl_df = nfl_df.drop(columns=unnecessary)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-457ef7eec7a4> in <module>
#       2               "passing_yards_away", "redzone_away", "redzone_home", "drives_away", "drives_home", "def_st_td_away",
#       3               "possession_away", "possession_home"]
# ----> 4 nfl_df = nfl_df.drop(columns=unnecessary)
#       5 nfl_df
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4167             level=level,
#    4168             inplace=inplace,
# -> 4169             errors=errors,
#    4170         )
#    4171
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# ...

# %%
nfl_df.head()
# Out:
#        date      away     home  passing_yards_home  rushing_yards_away  \
# 0  9/5/2002     49ers   Giants                 318                 113
# 1  9/8/2002      Jets    Bills                 242                  73
# 2  9/8/2002   Vikings    Bears                 288                 140
# 3  9/8/2002  Chargers  Bengals                 167                 241
# 4  9/8/2002    Chiefs   Browns                 352                 194
#
#    rushing_yards_home  total_yards_away  total_yards_home comp_att_away  \
# 0                  43               279               361         16-26
# 1                 142               266               384         24-30
# 2                  80               368               368         16-28
# 3                  36               401               203         15-19
# 4                  59               470               411         20-29
#
#   comp_att_home  ... fumbles_home int_away  int_home  turnovers_away  \
# ...
